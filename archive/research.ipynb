# %% [markdown]
# ### Models Lead — Open-Ended Brief
#
# ### Goal
# Build knowledge + code. You decide what to try; document what you learn.
#
# ---
#
# ### Ideas on what to work on (free to choose anything that sounds interesting or reliable)
#
# #### A) Modeling ideas (code + reading)
# - **Momentum families:** simple lookback (42/63/84d), risk-adjusted momentum, cross-sectional vs time-series.
# - **Mean-Variance variants:** rolling 252d μ/Σ, shrinkage covariances (Ledoit-Wolf), long-only simplex projection.
# - **Risk Parity / Vol targeting:** inverse-vol, equal risk contribution; monthly vs daily rebalance.
# - **Kelly-style scaling:** μ/σ² caps; compare to risk parity.
# - **RL stubs (env-agnostic for now):** PPO/A2C/TD3 wrappers skeleton; fixed seeds; save daily returns.
# - **Observation design:** returns-only vs simple features (rolling vol, z-scores) — argue pros/cons.
# - **Action design:** long-only softmax vs allowing a CASH sleeve or leverage (research trade-offs).
#
# #### B) Finance + market micro (short, useful)
# - **Transaction costs:** sensitivity curve Sharpe vs bps; turnover analysis.
# - **Rebalance cadence:** daily vs monthly — effect on Sharpe/turnover.
# - **Regime overlays:** rolling vol “turbulence” → go-to-cash rule; thresholds that make sense.
#
# #### C) Evaluation & selection (apples-to-apples)
# - **Metrics:** Sharpe, Sortino, Calmar, Omega, MaxDD, Turnover, Hit rate.
# - **Selector Lab:** rolling **Sharpe vs Sortino vs Calmar**; month-end switching; min-hold rules.
# - **Stat tests:** bootstrap CI for (Strategy − SPY) or (Strategy − EQW) mean daily return.
#
#
# #### You're encourged to use the notebook we already created and build off of it and create your own mini project to test ideas.
